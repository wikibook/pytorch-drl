# %% [markdown]
# ## 6.4 Prioritized Experience Replay 구현

# %%
# 구현에 사용할 패키지 임포트
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
# 애니메이션을 만드는 함수
# 참고 URL http://nbviewer.jupyter.org/github/patrickmineault
# /xcorr-notebooks/blob/master/Render%20OpenAI%20gym%20as%20GIF.ipynb
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display


def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0),
               dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                   interval=50)

    anim.save('movie_cartpole_prioritized_experience_replay.mp4')  # 애니메이션을 저장하는 부분
    display(display_animation(anim, default_mode='loop'))

# %%
# namedtuple 생성
from collections import namedtuple

Transition = namedtuple(
    'Transition', ('state', 'action', 'next_state', 'reward'))

# %%
# 상수 정의
ENV = 'CartPole-v0'  # 태스크 이름
GAMMA = 0.99  # 시간할인율
MAX_STEPS = 200  # 1에피소드 당 최대 단계 수
NUM_EPISODES = 500  # 최대 에피소드 수

# %%
# transition을 저장하기 위한 메모리 클래스


class ReplayMemory:

    def __init__(self, CAPACITY):
        self.capacity = CAPACITY  # 메모리의 최대 저장 건수
        self.memory = []  # 실제 transition을 저장할 변수
        self.index = 0  # 저장 위치를 가리킬 인덱스 변수

    def push(self, state, action, state_next, reward):
        '''transition = (state, action, state_next, reward)을 메모리에 저장'''

        if len(self.memory) < self.capacity:
            self.memory.append(None)  # 메모리가 가득차지 않은 경우

        # Transition이라는 namedtuple을 사용하여 키-값 쌍의 형태로 값을 저장
        self.memory[self.index] = Transition(state, action, state_next, reward)

        self.index = (self.index + 1) % self.capacity  # 다음 저장할 위치를 한 자리 뒤로 수정

    def sample(self, batch_size):
        '''batch_size 갯수 만큼 무작위로 저장된 transition을 추출'''
        return random.sample(self.memory, batch_size)

    def __len__(self):
        '''len 함수로 현재 저장된 transition 갯수를 반환'''
        return len(self.memory)

# %%
# TD오차를 저장할 메모리 클래스

TD_ERROR_EPSILON = 0.0001  # 오차에 더해줄 바이어스


class TDerrorMemory:

    def __init__(self, CAPACITY):
        self.capacity = CAPACITY  # 메모리의 최대 저장 건수
        self.memory = []  # 실제 TD오차를 저장할 변수
        self.index = 0  # 저장 위치를 가리킬 인덱스 변수

    def push(self, td_error):
        '''TD 오차를 메모리에 저장'''

        if len(self.memory) < self.capacity:
            self.memory.append(None)  # 메모리가 가득차지 않은 경우

        self.memory[self.index] = td_error
        self.index = (self.index + 1) % self.capacity  # 다음 저장할 위치를 한 자리 뒤로 수정

    def __len__(self):
        '''len 함수로 현재 저장된 갯수를 반환'''
        return len(self.memory)

    def get_prioritized_indexes(self, batch_size):
        '''TD 오차에 따른 확률로 인덱스를 추출'''

        # TD 오차의 합을 계산
        sum_absolute_td_error = np.sum(np.absolute(self.memory))
        sum_absolute_td_error += TD_ERROR_EPSILON * len(self.memory)  # 충분히 작은 값을 더해줌

        # batch_size 개만큼 난수를 생성하고 오름차순으로 정렬
        rand_list = np.random.uniform(0, sum_absolute_td_error, batch_size)
        rand_list = np.sort(rand_list)

        # 위에서 만든 난수로 인덱스를 결정
        indexes = []
        idx = 0
        tmp_sum_absolute_td_error = 0
        for rand_num in rand_list:
            while tmp_sum_absolute_td_error < rand_num:
                tmp_sum_absolute_td_error += (
                    abs(self.memory[idx]) + TD_ERROR_EPSILON)
                idx += 1

            # TD_ERROR_EPSILON을 더한 영향으로 인덱스가 실제 갯수를 초과했을 경우를 위한 보정
            if idx >= len(self.memory):
                idx = len(self.memory) - 1
            indexes.append(idx)

        return indexes

    def update_td_error(self, updated_td_errors):
        '''TD 오차를 업데이트'''
        self.memory = updated_td_errors

# %%
# 딥러닝 신경망 구성
# 신경망 설정(Chainer 스타일)
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):

    def __init__(self, n_in, n_mid, n_out):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in, n_mid)
        self.fc2 = nn.Linear(n_mid, n_mid)
        self.fc3 = nn.Linear(n_mid, n_out)

    def forward(self, x):
        h1 = F.relu(self.fc1(x))
        h2 = F.relu(self.fc2(h1))
        output = self.fc3(h2)
        return output

# %%
# 에이전트의 두뇌 역할을 하는 클래스, DDQN을 실제 수행한다 

import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000


class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # CartPoleの行動（右に左に押す）の2を取得

        # transition을 기억하기 위한 메모리 객체 생성
        self.memory = ReplayMemory(CAPACITY)

        # 신경망 구성
        n_in, n_mid, n_out = num_states, 32, num_actions
        self.main_q_network = Net(n_in, n_mid, n_out)  # Net 클래스를 사용
        self.target_q_network = Net(n_in, n_mid, n_out)  # Net 클래스를 사용
        print(self.main_q_network)  # 신경망의 구조를 출력

        # 최적화 기법 선택
        self.optimizer = optim.Adam(
            self.main_q_network.parameters(), lr=0.0001)

        # TD 오차를 기억하기 위한 메모리 객체 생성
        self.td_error_memory = TDerrorMemory(CAPACITY)

    def replay(self, episode):
        '''Experience Replayでネットワークの結合パラメータを学習'''

        # 1. 저장된 transition의 수를 확인
        if len(self.memory) < BATCH_SIZE:
            return

        # 2. 미니배치 생성
        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_states = self.make_minibatch(
            episode)

        # 3. 정답신호로 사용할 Q(s_t, a_t)를 계산
        self.expected_state_action_values = self.get_expected_state_action_values()

        # 4. 결합 가중치 수정
        self.update_main_q_network()

    def decide_action(self, state, episode):
        '''현재 상태로부터 행동을 결정함'''
        # ε-greedy 알고리즘에서 서서히 최적행동의 비중을 늘린다
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.main_q_network.eval()  # 신경망을 추론 모드로 전환
            with torch.no_grad():
                action = self.main_q_network(state).max(1)[1].view(1, 1)
            # 신경망 출력의 최댓값에 대한 인덱스 = max(1)[1]
            # .view(1,1)은 [torch.LongTensor of size 1] 을 size 1*1로 변환하는 역할을 한다

        else:
            # 행동을 무작위로 반환(0 혹은 1)
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])  # 행동을 무작위로 반환(0 혹은 1)
            # action은 [torch.LongTensor of size 1*1] 형태가 된다

        return action

    def make_minibatch(self, episode):
        '''2. ミニバッチの作成'''

        # 2.1 메모리 객체에서 미니배치를 추출
        if episode < 30:
            transitions = self.memory.sample(BATCH_SIZE)
        else:
            # TD 오차를 이용해 미니배치를 추출하도록 수정
            indexes = self.td_error_memory.get_prioritized_indexes(BATCH_SIZE)
            transitions = [self.memory.memory[n] for n in indexes]

        # 2.2 각 변수를 미니배치에 맞는 형태로 변형
        # transitions는 각 단계 별로 (state, action, state_next, reward) 형태로 BATCH_SIZE 갯수만큼 저장됨
        # 다시 말해, (state, action, state_next, reward) * BATCH_SIZE 형태가 된다
        # 이것을 미니배치로 만들기 위해
        # (state*BATCH_SIZE, action*BATCH_SIZE, state_next*BATCH_SIZE, reward*BATCH_SIZE) 형태로 변환한다
        batch = Transition(*zip(*transitions))

        # 2.3 각 변수의 요소를 미니배치에 맞게 변형하고, 신경망으로 다룰 수 있도록 Variable로 만든다
        # state를 예로 들면, [torch.FloatTensor of size 1*4] 형태의 요소가 BATCH_SIZE 갯수만큼 있는 형태이다
        # 이를 torch.FloatTensor of size BATCH_SIZE*4 형태로 변형한다
        # 상태, 행동, 보상, non_final 상태로 된 미니배치를 나타내는 Variable을 생성
        # cat은 Concatenates(연접)을 의미한다
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state
                                           if s is not None])

        return batch, state_batch, action_batch, reward_batch, non_final_next_states

    def get_expected_state_action_values(self):
        '''정답신호로 사용할 Q(s_t, a_t)를 계산'''

        # 3.1 신경망을 추론 모드로 전환
        self.main_q_network.eval()
        self.target_q_network.eval()

        # 3.2 신경망으로 Q(s_t, a_t)를 계산
        # self.model(state_batch)은 왼쪽, 오른쪽에 대한 Q값을 출력하며
        # [torch.FloatTensor of size BATCH_SIZEx2] 형태이다
        # 여기서부터는 실행한 행동 a_t에 대한 Q값을 계산하므로 action_batch에서 취한 행동 a_t가 
        # 왼쪽이냐 오른쪽이냐에 대한 인덱스를 구하고, 이에 대한 Q값을 gather 메서드로 모아온다
        self.state_action_values = self.main_q_network(
            self.state_batch).gather(1, self.action_batch)

        # 3.3 max{Q(s_t+1, a)}값을 계산한다 이때 다음 상태가 존재하는지에 주의해야 한다

        # cartpole이 done 상태가 아니고, next_state가 존재하는지 확인하는 인덱스 마스크를 만듬
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None,
                                                    self.batch.next_state)))
        # 먼저 전체를 0으로 초기화
        next_state_values = torch.zeros(BATCH_SIZE)
        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)

        # 다음 상태에서 Q값이 최대가 되는 행동 a_m을 Main Q-Network로 계산
        # 마지막에 붙은 [1]로 행동에 해당하는 인덱스를 구함
        a_m[non_final_mask] = self.main_q_network(
            self.non_final_next_states).detach().max(1)[1]

        # 다음 상태가 있는 것만을 걸러내고, size 32를 32*1로 변환
        a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)

        # 다음 상태가 있는 인덱스에 대해 행동 a_m의 Q값을 target Q-Network로 계산
        # detach() 메서드로 값을 꺼내옴
        # squeeze() 메서드로 size[minibatch*1]을 [minibatch]로 변환
        next_state_values[non_final_mask] = self.target_q_network(
            self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()

        # 3.4 정답신호로 사용할 Q(s_t, a_t)값을 Q러닝 식으로 계산한다
        expected_state_action_values = self.reward_batch + GAMMA * next_state_values

        return expected_state_action_values

    def update_main_q_network(self):
        '''4. 결합 가중치 수정'''

        # 4.1 신경망을 학습 모드로 전환
        self.main_q_network.train()

        # 4.2 손실함수를 계산 (smooth_l1_loss는 Huber 함수)
        # expected_state_action_values은
        # size가 [minibatch]이므로 unsqueeze하여 [minibatch*1]로 만든다
        loss = F.smooth_l1_loss(self.state_action_values,
                                self.expected_state_action_values.unsqueeze(1))

        # 4.3 결합 가중치를 수정한다
        self.optimizer.zero_grad()  # 경사를 초기화
        loss.backward()  # 역전파 계산
        self.optimizer.step()  # 결합 가중치 수정

    def update_target_q_network(self):  # DDQN에서 추가됨
        '''Target Q-Network을 Main Q-Network와 맞춤'''
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

    def update_td_error_memory(self):  # PrioritizedExperienceReplay에서 추가됨
        '''TD 오차 메모리에 저장된 TD 오차를 업데이트'''

        # 신경망을 추론 모드로 전환
        self.main_q_network.eval()
        self.target_q_network.eval()

        # 전체 transition으로 미니배치를 생성
        transitions = self.memory.memory
        batch = Transition(*zip(*transitions))

        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state
                                           if s is not None])

        # 신경망의 출력 Q(s_t, a_t)를 계산
        state_action_values = self.main_q_network(
            state_batch).gather(1, action_batch)

        # cartpole이 done 상태가 아니고, next_state가 존재하는지 확인하는 인덱스 마스크를 만듬
        non_final_mask = torch.ByteTensor(
            tuple(map(lambda s: s is not None, batch.next_state)))

        # 먼저 전체를 0으로 초기화, 크기는 기억한 transition 갯수만큼
        next_state_values = torch.zeros(len(self.memory))
        a_m = torch.zeros(len(self.memory)).type(torch.LongTensor)

        # 다음 상태에서 Q값이 최대가 되는 행동 a_m을 Main Q-Network로 계산
        # 마지막에 붙은 [1]로 행동에 해당하는 인덱스를 구함
        a_m[non_final_mask] = self.main_q_network(
            non_final_next_states).detach().max(1)[1]

        # 다음 상태가 있는 것만을 걸러내고, size 32를 32*1로 변환
        a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)

        # 다음 상태가 있는 인덱스에 대해 행동 a_m의 Q값을 target Q-Network로 계산
        # detach() 메서드로 값을 꺼내옴
        # squeeze() 메서드로 size[minibatch*1]을 [minibatch]로 변환
        next_state_values[non_final_mask] = self.target_q_network(
            non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()

        # TD 오차를 계산
        td_errors = (reward_batch + GAMMA * next_state_values) - \
            state_action_values.squeeze()
        # state_action_values는 size[minibatch*1]이므로 squeeze() 메서드로 size[minibatch]로 변환

        # TD 오차 메모리를 업데이트. Tensor를 detach() 메서드로 꺼내와서 NumPy 변수로 변환하고 다시 파이썬 리스트로 변환
        self.td_error_memory.memory = td_errors.detach().numpy().tolist()

# %%
# CartPole 태스크의 에이전트 클래스. 봉 달린 수레 자체라고 보면 된다


class Agent:
    def __init__(self, num_states, num_actions):
        '''태스크의 상태 및 행동의 가짓수를 설정'''
        self.brain = Brain(num_states, num_actions)  # 에이전트의 행동을 결정할 두뇌 역할 객체를 생성

    def update_q_function(self, episode):
        '''Q함수를 수정'''
        self.brain.replay(episode)

    def get_action(self, state, episode):
        '''행동을 결정'''
        action = self.brain.decide_action(state, episode)
        return action

    def memorize(self, state, action, state_next, reward):
        '''memory 객체에 state, action, state_next, reward 내용을 저장'''
        self.brain.memory.push(state, action, state_next, reward)

    def update_target_q_function(self):
        '''Target Q-Network을 Main Q-Network와 맞춤'''
        self.brain.update_target_q_network()
        
    def memorize_td_error(self, td_error):  # PrioritizedExperienceReplay에서 추가
        '''TD 오차 메모리에 TD 오차를 저장'''
        self.brain.td_error_memory.push(td_error)
        
    def update_td_error_memory(self):  # PrioritizedExperienceReplay에서 추가
        '''TD 오차 메모리의 TD 오차를 업데이트'''
        self.brain.update_td_error_memory()

# %%
# CartPole을 실행하는 환경 클래스


class Environment:

    def __init__(self):
        self.env = gym.make(ENV)  # 태스크를 설정
        num_states = self.env.observation_space.shape[0]  # 태스크의 상태 변수 수(4)를 받아옴
        num_actions = self.env.action_space.n  # 태스크의 행동 가짓수(2)를 받아옴
        # 에이전트 역할을 할 객체를 생성
        self.agent = Agent(num_states, num_actions)

    def run(self):
        '''실행'''
        episode_10_list = np.zeros(10)  # 최근 10에피소드 동안 버틴 단계 수를 저장함(평균 단계 수를 출력할 때 사용)
        complete_episodes = 0  # 현재까지 195단계를 버틴 에피소드 수
        episode_final = False  # 마지막 에피소드 여부
        frames = []  # 애니메이션을 만들기 위해 마지막 에피소드의 프레임을 저장할 배열

        for episode in range(NUM_EPISODES):  # 최대 에피소드 수만큼 반복
            observation = self.env.reset()  # 환경 초기화

            state = observation  # 관측을 변환없이 그대로 상태 s로 사용
            state = torch.from_numpy(state).type(
                torch.FloatTensor)  # NumPy 변수를 파이토치 텐서로 변환
            state = torch.unsqueeze(state, 0)  # size 4를 size 1*4로 변환

            for step in range(MAX_STEPS):  # 1 에피소드에 해당하는 반복문

                # 애니메이션 만드는 부분을 주석처리
                #if episode_final is True:  # 마지막 에피소드에서는 각 시각의 이미지를 frames에 저장한다
                    # frames.append(self.env.render(mode='rgb_array'))

                action = self.agent.get_action(state, episode)  # 다음 행동을 결정

                # 행동 a_t를 실행하여 다음 상태 s_{t+1}과 done 플래그 값을 결정
                # action에 .item()을 호출하여 행동 내용을 구함
                observation_next, _, done, _ = self.env.step(
                    action.item())  # reward와 info는 사용하지 않으므로 _로 처리

                # 보상을 부여하고 episode의 종료 판정 및 state_next를 설정한다
                if done:  # 단계 수가 200을 넘었거나 봉이 일정 각도 이상 기울면 done이 True가 됨
                    state_next = None  # 다음 상태가 없으므로 None으로

                    # 최근 10 에피소드에서 버틴 단계 수를 리스트에 저장
                    episode_10_list = np.hstack(
                        (episode_10_list[1:], step + 1))

                    if step < 195:
                        reward = torch.FloatTensor(
                            [-1.0])  # 도중에 봉이 쓰러졌다면 페널티로 보상 -1을 부여
                        complete_episodes = 0  # 연속 성공 에피소드 기록을 초기화
                    else:
                        reward = torch.FloatTensor([1.0])  # 봉이 서 있는 채로 에피소드를 마쳤다면 보상 1 부여
                        complete_episodes = complete_episodes + 1  # 연속 성공 에피소드 기록을 갱신
                else:
                    reward = torch.FloatTensor([0.0])  # 그 외의 경우는 보상 0을 부여
                    state_next = observation_next  # 관측 결과를 그대로 상태로 사용
                    state_next = torch.from_numpy(state_next).type(
                        torch.FloatTensor)  # numpy 변수를 파이토치 텐서로 변환
                    state_next = torch.unsqueeze(
                        state_next, 0)  # size 4를 size 1*4로 변환

                # 메모리에 경험을 저장
                self.agent.memorize(state, action, state_next, reward)

                # TD 오차 메모리에 TD 오차를 저장
                self.agent.memorize_td_error(0)  # 여기서는 정확한 값 대신 0을 저장함

                # PrioritizedExperienceReplay로 Q함수를 수정
                self.agent.update_q_function(episode)

                # 관측 결과를 업데이트
                state = state_next

                # 에피소드 종료 처리
                if done:
                    print('%d Episode: Finished after %d steps：최근 10 에피소드의 평균 단계 수 = %.1lf' % (
                        episode, step + 1, episode_10_list.mean()))

                    # TD 오차 메모리의 TD 오차를 업데이트
                    self.agent.update_td_error_memory()

                    # DDQN으로 추가된 부분 2에피소드마다 한번씩 Target Q-Network을 Main Q-Network와 맞춰줌
                    if(episode % 2 == 0):
                        self.agent.update_target_q_function()
                    break

            if episode_final is True:
                # 애니메이션 생성 부분을 주석처리함
                # 애니메이션 생성 및 저장
                #display_frames_as_gif(frames)
                break

            # 10 에피소드 연속으로 195단계를 버티면 태스크 성공
            if complete_episodes >= 10:
                print('10 에피소드 연속 성공')
                episode_final = True  # 다음 에피소드에서 애니메이션을 생성

# %%
# 실행 엔트리 포인트
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode: Finished after 12 steps：최근 10 에피소드의 평균 단계 수 = 1.2
# 1 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 2.8
# 2 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 3.8
# 3 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 4.8
# 4 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 5.8
# 5 Episode: Finished after 8 steps：최근 10 에피소드의 평균 단계 수 = 6.6
# 6 Episode: Finished after 8 steps：최근 10 에피소드의 평균 단계 수 = 7.4
# 7 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 8.3
# 8 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 9.7
# 9 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 10.7
# 10 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 10.5
# 11 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 9.8
# 12 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 9.8
# 13 Episode: Finished after 8 steps：최근 10 에피소드의 평균 단계 수 = 9.6
# 14 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 10.0
# 15 Episode: Finished after 11 steps：최근 10 에피소드의 평균 단계 수 = 10.3
# 16 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 10.4
# 17 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 10.5
# 18 Episode: Finished after 47 steps：최근 10 에피소드의 평균 단계 수 = 13.8
# 19 Episode: Finished after 11 steps：최근 10 에피소드의 평균 단계 수 = 13.9
# 20 Episode: Finished after 28 steps：최근 10 에피소드의 평균 단계 수 = 15.7
# 21 Episode: Finished after 25 steps：최근 10 에피소드의 평균 단계 수 = 17.3
# 22 Episode: Finished after 20 steps：최근 10 에피소드의 평균 단계 수 = 18.3
# 23 Episode: Finished after 26 steps：최근 10 에피소드의 평균 단계 수 = 20.1
# 24 Episode: Finished after 21 steps：최근 10 에피소드의 평균 단계 수 = 20.8
# 25 Episode: Finished after 20 steps：최근 10 에피소드의 평균 단계 수 = 21.7
# 26 Episode: Finished after 13 steps：최근 10 에피소드의 평균 단계 수 = 22.1
# 27 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 22.6
# 28 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 19.5
# 29 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 20.0
# 30 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 18.6
# 31 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 17.7
# 32 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 17.3
# 33 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 16.1
# 34 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 15.4
# 35 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 15.0
# 36 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 15.1
# 37 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 15.0
# 38 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 15.0
# 39 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 15.3
# 40 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 16.1
# 41 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 15.9
# 42 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 16.1
# 43 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 16.5
# 44 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 16.5
# 45 Episode: Finished after 21 steps：최근 10 에피소드의 평균 단계 수 = 17.0
# 46 Episode: Finished after 21 steps：최근 10 에피소드의 평균 단계 수 = 17.7
# 47 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 18.1
# 48 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 18.4
# 49 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 18.1
# 50 Episode: Finished after 24 steps：최근 10 에피소드의 평균 단계 수 = 18.3
# 51 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 18.8
# 52 Episode: Finished after 17 steps：최근 10 에피소드의 평균 단계 수 = 18.7
# 53 Episode: Finished after 24 steps：최근 10 에피소드의 평균 단계 수 = 19.3
# 54 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 19.4
# 55 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 18.8
# 56 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 18.3
# 57 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 18.0
# 58 Episode: Finished after 17 steps：최근 10 에피소드의 평균 단계 수 = 17.8
# 59 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 18.1
# 60 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 17.5
# 61 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 17.5
# 62 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 17.6
# 63 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 17.4
# 64 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 17.8
# 65 Episode: Finished after 25 steps：최근 10 에피소드의 평균 단계 수 = 18.8
# 66 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 19.4
# 67 Episode: Finished after 27 steps：최근 10 에피소드의 평균 단계 수 = 20.6
# 68 Episode: Finished after 25 steps：최근 10 에피소드의 평균 단계 수 = 21.4
# 69 Episode: Finished after 25 steps：최근 10 에피소드의 평균 단계 수 = 22.0
# 70 Episode: Finished after 31 steps：최근 10 에피소드의 평균 단계 수 = 23.3
# 71 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 23.2
# 72 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 23.6
# 73 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 23.3
# 74 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 23.2
# 75 Episode: Finished after 25 steps：최근 10 에피소드의 평균 단계 수 = 23.2
# 76 Episode: Finished after 27 steps：최근 10 에피소드의 평균 단계 수 = 23.7
# 77 Episode: Finished after 24 steps：최근 10 에피소드의 평균 단계 수 = 23.4
# 78 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 22.8
# 79 Episode: Finished after 32 steps：최근 10 에피소드의 평균 단계 수 = 23.5
# 80 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 22.2
# 81 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 22.6
# 82 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 21.9
# 83 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 21.5
# 84 Episode: Finished after 24 steps：최근 10 에피소드의 평균 단계 수 = 22.1
# 85 Episode: Finished after 20 steps：최근 10 에피소드의 평균 단계 수 = 21.6
# 86 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 20.7
# 87 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 20.1
# 88 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 19.7
# 89 Episode: Finished after 13 steps：최근 10 에피소드의 평균 단계 수 = 17.8
# 90 Episode: Finished after 20 steps：최근 10 에피소드의 평균 단계 수 = 18.0
# 91 Episode: Finished after 24 steps：최근 10 에피소드의 평균 단계 수 = 18.2
# 92 Episode: Finished after 37 steps：최근 10 에피소드의 평균 단계 수 = 20.4
# 93 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 20.7
# 94 Episode: Finished after 23 steps：최근 10 에피소드의 평균 단계 수 = 20.6
# 95 Episode: Finished after 35 steps：최근 10 에피소드의 평균 단계 수 = 22.1
# 96 Episode: Finished after 28 steps：최근 10 에피소드의 평균 단계 수 = 23.1
# 97 Episode: Finished after 33 steps：최근 10 에피소드의 평균 단계 수 = 24.6
# 98 Episode: Finished after 21 steps：최근 10 에피소드의 평균 단계 수 = 25.2
# 99 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 25.4
# 100 Episode: Finished after 21 steps：최근 10 에피소드의 평균 단계 수 = 25.5
# 101 Episode: Finished after 35 steps：최근 10 에피소드의 평균 단계 수 = 26.6
# 102 Episode: Finished after 34 steps：최근 10 에피소드의 평균 단계 수 = 26.3
# 103 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 26.4
# 104 Episode: Finished after 55 steps：최근 10 에피소드의 평균 단계 수 = 29.6
# 105 Episode: Finished after 32 steps：최근 10 에피소드의 평균 단계 수 = 29.3
# 106 Episode: Finished after 31 steps：최근 10 에피소드의 평균 단계 수 = 29.6
# 107 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 28.2
# 108 Episode: Finished after 20 steps：최근 10 에피소드의 평균 단계 수 = 28.1
# 109 Episode: Finished after 36 steps：최근 10 에피소드의 평균 단계 수 = 30.2
# 110 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 30.3
# 111 Episode: Finished after 32 steps：최근 10 에피소드의 평균 단계 수 = 30.0
# 112 Episode: Finished after 40 steps：최근 10 에피소드의 평균 단계 수 = 30.6
# 113 Episode: Finished after 39 steps：최근 10 에피소드의 평균 단계 수 = 32.6
# 114 Episode: Finished after 54 steps：최근 10 에피소드의 평균 단계 수 = 32.5
# 115 Episode: Finished after 32 steps：최근 10 에피소드의 평균 단계 수 = 32.5
# 116 Episode: Finished after 41 steps：최근 10 에피소드의 평균 단계 수 = 33.5
# 117 Episode: Finished after 38 steps：최근 10 에피소드의 평균 단계 수 = 35.4
# 118 Episode: Finished after 33 steps：최근 10 에피소드의 평균 단계 수 = 36.7
# 119 Episode: Finished after 29 steps：최근 10 에피소드의 평균 단계 수 = 36.0
# 120 Episode: Finished after 61 steps：최근 10 에피소드의 평균 단계 수 = 39.9
# 121 Episode: Finished after 42 steps：최근 10 에피소드의 평균 단계 수 = 40.9
# 122 Episode: Finished after 29 steps：최근 10 에피소드의 평균 단계 수 = 39.8
# 123 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 37.8
# 124 Episode: Finished after 24 steps：최근 10 에피소드의 평균 단계 수 = 34.8
# 125 Episode: Finished after 46 steps：최근 10 에피소드의 평균 단계 수 = 36.2
# 126 Episode: Finished after 27 steps：최근 10 에피소드의 평균 단계 수 = 34.8
# 127 Episode: Finished after 24 steps：최근 10 에피소드의 평균 단계 수 = 33.4
# 128 Episode: Finished after 25 steps：최근 10 에피소드의 평균 단계 수 = 32.6
# 129 Episode: Finished after 23 steps：최근 10 에피소드의 평균 단계 수 = 32.0
# 130 Episode: Finished after 21 steps：최근 10 에피소드의 평균 단계 수 = 28.0
# 131 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 25.4
# 132 Episode: Finished after 23 steps：최근 10 에피소드의 평균 단계 수 = 24.8
# 133 Episode: Finished after 24 steps：최근 10 에피소드의 평균 단계 수 = 25.3
# 134 Episode: Finished after 26 steps：최근 10 에피소드의 평균 단계 수 = 25.5
# 135 Episode: Finished after 50 steps：최근 10 에피소드의 평균 단계 수 = 25.9
# 136 Episode: Finished after 53 steps：최근 10 에피소드의 평균 단계 수 = 28.5
# 137 Episode: Finished after 32 steps：최근 10 에피소드의 평균 단계 수 = 29.3
# 138 Episode: Finished after 20 steps：최근 10 에피소드의 평균 단계 수 = 28.8
# 139 Episode: Finished after 31 steps：최근 10 에피소드의 평균 단계 수 = 29.6
# 140 Episode: Finished after 35 steps：최근 10 에피소드의 평균 단계 수 = 31.0
# 141 Episode: Finished after 26 steps：최근 10 에피소드의 평균 단계 수 = 32.0
# 142 Episode: Finished after 31 steps：최근 10 에피소드의 평균 단계 수 = 32.8
# 143 Episode: Finished after 32 steps：최근 10 에피소드의 평균 단계 수 = 33.6
# 144 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 32.9
# 145 Episode: Finished after 73 steps：최근 10 에피소드의 평균 단계 수 = 35.2
# 146 Episode: Finished after 31 steps：최근 10 에피소드의 평균 단계 수 = 33.0
# 147 Episode: Finished after 30 steps：최근 10 에피소드의 평균 단계 수 = 32.8
# 148 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 32.6
# 149 Episode: Finished after 25 steps：최근 10 에피소드의 평균 단계 수 = 32.0
# 150 Episode: Finished after 23 steps：최근 10 에피소드의 평균 단계 수 = 30.8
# 151 Episode: Finished after 28 steps：최근 10 에피소드의 평균 단계 수 = 31.0
# 152 Episode: Finished after 21 steps：최근 10 에피소드의 평균 단계 수 = 30.0
# 153 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 29.0
# 154 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 29.0
# 155 Episode: Finished after 27 steps：최근 10 에피소드의 평균 단계 수 = 24.4
# 156 Episode: Finished after 80 steps：최근 10 에피소드의 평균 단계 수 = 29.3
# 157 Episode: Finished after 27 steps：최근 10 에피소드의 평균 단계 수 = 29.0
# 158 Episode: Finished after 29 steps：최근 10 에피소드의 평균 단계 수 = 30.1
# 159 Episode: Finished after 37 steps：최근 10 에피소드의 평균 단계 수 = 31.3
# 160 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 31.2
# 161 Episode: Finished after 32 steps：최근 10 에피소드의 평균 단계 수 = 31.6
# 162 Episode: Finished after 33 steps：최근 10 에피소드의 평균 단계 수 = 32.8
# 163 Episode: Finished after 33 steps：최근 10 에피소드의 평균 단계 수 = 33.9
# 164 Episode: Finished after 27 steps：최근 10 에피소드의 평균 단계 수 = 34.7
# 165 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 34.2
# 166 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 28.1
# 167 Episode: Finished after 101 steps：최근 10 에피소드의 평균 단계 수 = 35.5
# 168 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 34.8
# 169 Episode: Finished after 47 steps：최근 10 에피소드의 평균 단계 수 = 35.8
# 170 Episode: Finished after 30 steps：최근 10 에피소드의 평균 단계 수 = 36.6
# 171 Episode: Finished after 44 steps：최근 10 에피소드의 평균 단계 수 = 37.8
# 172 Episode: Finished after 21 steps：최근 10 에피소드의 평균 단계 수 = 36.6
# 173 Episode: Finished after 20 steps：최근 10 에피소드의 평균 단계 수 = 35.3
# 174 Episode: Finished after 28 steps：최근 10 에피소드의 평균 단계 수 = 35.4
# 175 Episode: Finished after 27 steps：최근 10 에피소드의 평균 단계 수 = 35.9
# 176 Episode: Finished after 61 steps：최근 10 에피소드의 평균 단계 수 = 40.1
# 177 Episode: Finished after 35 steps：최근 10 에피소드의 평균 단계 수 = 33.5
# 178 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 33.2
# 179 Episode: Finished after 21 steps：최근 10 에피소드의 평균 단계 수 = 30.6
# 180 Episode: Finished after 30 steps：최근 10 에피소드의 평균 단계 수 = 30.6
# 181 Episode: Finished after 24 steps：최근 10 에피소드의 평균 단계 수 = 28.6
# 182 Episode: Finished after 26 steps：최근 10 에피소드의 평균 단계 수 = 29.1
# 183 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 28.9
# 184 Episode: Finished after 28 steps：최근 10 에피소드의 평균 단계 수 = 28.9
# 185 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 28.1
# 186 Episode: Finished after 30 steps：최근 10 에피소드의 평균 단계 수 = 25.0
# 187 Episode: Finished after 20 steps：최근 10 에피소드의 평균 단계 수 = 23.5
# 188 Episode: Finished after 35 steps：최근 10 에피소드의 평균 단계 수 = 25.1
# 189 Episode: Finished after 130 steps：최근 10 에피소드의 평균 단계 수 = 36.0
# 190 Episode: Finished after 45 steps：최근 10 에피소드의 평균 단계 수 = 37.5
# 191 Episode: Finished after 50 steps：최근 10 에피소드의 평균 단계 수 = 40.1
# 192 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 39.3
# 193 Episode: Finished after 21 steps：최근 10 에피소드의 평균 단계 수 = 39.6
# 194 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 38.6
# 195 Episode: Finished after 73 steps：최근 10 에피소드의 평균 단계 수 = 44.0
# 196 Episode: Finished after 97 steps：최근 10 에피소드의 평균 단계 수 = 50.7
# 197 Episode: Finished after 157 steps：최근 10 에피소드의 평균 단계 수 = 64.4
# 198 Episode: Finished after 75 steps：최근 10 에피소드의 평균 단계 수 = 68.4
# 199 Episode: Finished after 154 steps：최근 10 에피소드의 평균 단계 수 = 70.8
# 200 Episode: Finished after 55 steps：최근 10 에피소드의 평균 단계 수 = 71.8
# 201 Episode: Finished after 45 steps：최근 10 에피소드의 평균 단계 수 = 71.3
# 202 Episode: Finished after 52 steps：최근 10 에피소드의 평균 단계 수 = 74.7
# 203 Episode: Finished after 87 steps：최근 10 에피소드의 평균 단계 수 = 81.3
# 204 Episode: Finished after 91 steps：최근 10 에피소드의 평균 단계 수 = 88.6
# 205 Episode: Finished after 147 steps：최근 10 에피소드의 평균 단계 수 = 96.0
# 206 Episode: Finished after 142 steps：최근 10 에피소드의 평균 단계 수 = 100.5
# 207 Episode: Finished after 120 steps：최근 10 에피소드의 평균 단계 수 = 96.8
# 208 Episode: Finished after 70 steps：최근 10 에피소드의 평균 단계 수 = 96.3
# 209 Episode: Finished after 93 steps：최근 10 에피소드의 평균 단계 수 = 90.2
# 210 Episode: Finished after 112 steps：최근 10 에피소드의 평균 단계 수 = 95.9
# 211 Episode: Finished after 113 steps：최근 10 에피소드의 평균 단계 수 = 102.7
# 212 Episode: Finished after 150 steps：최근 10 에피소드의 평균 단계 수 = 112.5
# 213 Episode: Finished after 137 steps：최근 10 에피소드의 평균 단계 수 = 117.5
# 214 Episode: Finished after 97 steps：최근 10 에피소드의 평균 단계 수 = 118.1
# 215 Episode: Finished after 170 steps：최근 10 에피소드의 평균 단계 수 = 120.4
# 216 Episode: Finished after 133 steps：최근 10 에피소드의 평균 단계 수 = 119.5
# 217 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 127.5
# 218 Episode: Finished after 148 steps：최근 10 에피소드의 평균 단계 수 = 135.3
# 219 Episode: Finished after 138 steps：최근 10 에피소드의 평균 단계 수 = 139.8
# 220 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 148.6
# 221 Episode: Finished after 121 steps：최근 10 에피소드의 평균 단계 수 = 149.4
# 222 Episode: Finished after 104 steps：최근 10 에피소드의 평균 단계 수 = 144.8
# 223 Episode: Finished after 107 steps：최근 10 에피소드의 평균 단계 수 = 141.8
# 224 Episode: Finished after 151 steps：최근 10 에피소드의 평균 단계 수 = 147.2
# 225 Episode: Finished after 110 steps：최근 10 에피소드의 평균 단계 수 = 141.2
# 226 Episode: Finished after 196 steps：최근 10 에피소드의 평균 단계 수 = 147.5
# 227 Episode: Finished after 153 steps：최근 10 에피소드의 평균 단계 수 = 142.8
# 228 Episode: Finished after 108 steps：최근 10 에피소드의 평균 단계 수 = 138.8
# 229 Episode: Finished after 150 steps：최근 10 에피소드의 평균 단계 수 = 140.0
# 230 Episode: Finished after 133 steps：최근 10 에피소드의 평균 단계 수 = 133.3
# 231 Episode: Finished after 129 steps：최근 10 에피소드의 평균 단계 수 = 134.1
# 232 Episode: Finished after 128 steps：최근 10 에피소드의 평균 단계 수 = 136.5
# 233 Episode: Finished after 106 steps：최근 10 에피소드의 평균 단계 수 = 136.4
# 234 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 141.3
# 235 Episode: Finished after 160 steps：최근 10 에피소드의 평균 단계 수 = 146.3
# 236 Episode: Finished after 109 steps：최근 10 에피소드의 평균 단계 수 = 137.6
# 237 Episode: Finished after 146 steps：최근 10 에피소드의 평균 단계 수 = 136.9
# 238 Episode: Finished after 148 steps：최근 10 에피소드의 평균 단계 수 = 140.9
# 239 Episode: Finished after 80 steps：최근 10 에피소드의 평균 단계 수 = 133.9
# 240 Episode: Finished after 113 steps：최근 10 에피소드의 평균 단계 수 = 131.9
# 241 Episode: Finished after 132 steps：최근 10 에피소드의 평균 단계 수 = 132.2
# 242 Episode: Finished after 176 steps：최근 10 에피소드의 평균 단계 수 = 137.0
# 243 Episode: Finished after 108 steps：최근 10 에피소드의 평균 단계 수 = 137.2
# 244 Episode: Finished after 113 steps：최근 10 에피소드의 평균 단계 수 = 128.5
# 245 Episode: Finished after 195 steps：최근 10 에피소드의 평균 단계 수 = 132.0
# 246 Episode: Finished after 124 steps：최근 10 에피소드의 평균 단계 수 = 133.5
# 247 Episode: Finished after 102 steps：최근 10 에피소드의 평균 단계 수 = 129.1
# 248 Episode: Finished after 92 steps：최근 10 에피소드의 평균 단계 수 = 123.5
# 249 Episode: Finished after 152 steps：최근 10 에피소드의 평균 단계 수 = 130.7
# 250 Episode: Finished after 56 steps：최근 10 에피소드의 평균 단계 수 = 125.0
# 251 Episode: Finished after 146 steps：최근 10 에피소드의 평균 단계 수 = 126.4
# 252 Episode: Finished after 112 steps：최근 10 에피소드의 평균 단계 수 = 120.0
# 253 Episode: Finished after 93 steps：최근 10 에피소드의 평균 단계 수 = 118.5
# 254 Episode: Finished after 159 steps：최근 10 에피소드의 평균 단계 수 = 123.1
# 255 Episode: Finished after 46 steps：최근 10 에피소드의 평균 단계 수 = 108.2
# 256 Episode: Finished after 66 steps：최근 10 에피소드의 평균 단계 수 = 102.4
# 257 Episode: Finished after 54 steps：최근 10 에피소드의 평균 단계 수 = 97.6
# 258 Episode: Finished after 64 steps：최근 10 에피소드의 평균 단계 수 = 94.8
# 259 Episode: Finished after 97 steps：최근 10 에피소드의 평균 단계 수 = 89.3
# 260 Episode: Finished after 146 steps：최근 10 에피소드의 평균 단계 수 = 98.3
# 261 Episode: Finished after 52 steps：최근 10 에피소드의 평균 단계 수 = 88.9
# 262 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 97.7
# 263 Episode: Finished after 50 steps：최근 10 에피소드의 평균 단계 수 = 93.4
# 264 Episode: Finished after 55 steps：최근 10 에피소드의 평균 단계 수 = 83.0
# 265 Episode: Finished after 82 steps：최근 10 에피소드의 평균 단계 수 = 86.6
# 266 Episode: Finished after 96 steps：최근 10 에피소드의 평균 단계 수 = 89.6
# 267 Episode: Finished after 66 steps：최근 10 에피소드의 평균 단계 수 = 90.8
# 268 Episode: Finished after 61 steps：최근 10 에피소드의 평균 단계 수 = 90.5
# 269 Episode: Finished after 57 steps：최근 10 에피소드의 평균 단계 수 = 86.5
# 270 Episode: Finished after 63 steps：최근 10 에피소드의 평균 단계 수 = 78.2
# 271 Episode: Finished after 46 steps：최근 10 에피소드의 평균 단계 수 = 77.6
# 272 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 77.6
# 273 Episode: Finished after 56 steps：최근 10 에피소드의 평균 단계 수 = 78.2
# 274 Episode: Finished after 141 steps：최근 10 에피소드의 평균 단계 수 = 86.8
# 275 Episode: Finished after 113 steps：최근 10 에피소드의 평균 단계 수 = 89.9
# 276 Episode: Finished after 85 steps：최근 10 에피소드의 평균 단계 수 = 88.8
# 277 Episode: Finished after 189 steps：최근 10 에피소드의 평균 단계 수 = 101.1
# 278 Episode: Finished after 109 steps：최근 10 에피소드의 평균 단계 수 = 105.9
# 279 Episode: Finished after 53 steps：최근 10 에피소드의 평균 단계 수 = 105.5
# 280 Episode: Finished after 169 steps：최근 10 에피소드의 평균 단계 수 = 116.1
# 281 Episode: Finished after 85 steps：최근 10 에피소드의 평균 단계 수 = 120.0
# 282 Episode: Finished after 98 steps：최근 10 에피소드의 평균 단계 수 = 109.8
# 283 Episode: Finished after 110 steps：최근 10 에피소드의 평균 단계 수 = 115.2
# 284 Episode: Finished after 58 steps：최근 10 에피소드의 평균 단계 수 = 106.9
# 285 Episode: Finished after 97 steps：최근 10 에피소드의 평균 단계 수 = 105.3
# 286 Episode: Finished after 177 steps：최근 10 에피소드의 평균 단계 수 = 114.5
# 287 Episode: Finished after 167 steps：최근 10 에피소드의 평균 단계 수 = 112.3
# 288 Episode: Finished after 178 steps：최근 10 에피소드의 평균 단계 수 = 119.2
# 289 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 133.9
# 290 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 137.0
# 291 Episode: Finished after 152 steps：최근 10 에피소드의 평균 단계 수 = 143.7
# 292 Episode: Finished after 132 steps：최근 10 에피소드의 평균 단계 수 = 147.1
# 293 Episode: Finished after 90 steps：최근 10 에피소드의 평균 단계 수 = 145.1
# 294 Episode: Finished after 164 steps：최근 10 에피소드의 평균 단계 수 = 155.7
# 295 Episode: Finished after 137 steps：최근 10 에피소드의 평균 단계 수 = 159.7
# 296 Episode: Finished after 140 steps：최근 10 에피소드의 평균 단계 수 = 156.0
# 297 Episode: Finished after 117 steps：최근 10 에피소드의 평균 단계 수 = 151.0
# 298 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 153.2
# 299 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 153.2
# 300 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 153.2
# 301 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 158.0
# 302 Episode: Finished after 133 steps：최근 10 에피소드의 평균 단계 수 = 158.1
# 303 Episode: Finished after 153 steps：최근 10 에피소드의 평균 단계 수 = 164.4
# 304 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 168.0
# 305 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 174.3
# 306 Episode: Finished after 163 steps：최근 10 에피소드의 평균 단계 수 = 176.6
# 307 Episode: Finished after 105 steps：최근 10 에피소드의 평균 단계 수 = 175.4
# 308 Episode: Finished after 188 steps：최근 10 에피소드의 평균 단계 수 = 174.2
# 309 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 174.2
# 310 Episode: Finished after 178 steps：최근 10 에피소드의 평균 단계 수 = 172.0
# 311 Episode: Finished after 125 steps：최근 10 에피소드의 평균 단계 수 = 164.5
# 312 Episode: Finished after 129 steps：최근 10 에피소드의 평균 단계 수 = 164.1
# 313 Episode: Finished after 195 steps：최근 10 에피소드의 평균 단계 수 = 168.3
# 314 Episode: Finished after 197 steps：최근 10 에피소드의 평균 단계 수 = 168.0
# 315 Episode: Finished after 156 steps：최근 10 에피소드의 평균 단계 수 = 163.6
# 316 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 167.3
# 317 Episode: Finished after 194 steps：최근 10 에피소드의 평균 단계 수 = 176.2
# 318 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 177.4
# 319 Episode: Finished after 175 steps：최근 10 에피소드의 평균 단계 수 = 174.9
# 320 Episode: Finished after 190 steps：최근 10 에피소드의 평균 단계 수 = 176.1
# 321 Episode: Finished after 153 steps：최근 10 에피소드의 평균 단계 수 = 178.9
# 322 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 186.0
# 323 Episode: Finished after 190 steps：최근 10 에피소드의 평균 단계 수 = 185.5
# 324 Episode: Finished after 158 steps：최근 10 에피소드의 평균 단계 수 = 181.6
# 325 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 186.0
# 326 Episode: Finished after 163 steps：최근 10 에피소드의 평균 단계 수 = 182.3
# 327 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 182.9
# 328 Episode: Finished after 169 steps：최근 10 에피소드의 평균 단계 수 = 179.8
# 329 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 182.3
# 330 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 183.3
# 331 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 188.0
# 332 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 188.0
# 333 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 189.0
# 334 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 193.2
# 335 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 193.2
# 336 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 196.9
# 337 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 196.9
# 338 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 200.0
# 10 에피소드 연속 성공
# 339 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 200.0
